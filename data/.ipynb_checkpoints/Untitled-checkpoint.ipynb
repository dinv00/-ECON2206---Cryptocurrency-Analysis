# %%
import pandas as pd
df1 = pd.read_csv('BTC-USD.csv')
df2=pd.read_csv('ETH-USD.csv')
df3=pd.read_csv('LEO-USD.csv')

# %%
df3.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  2020-12-31  1.353193  1.358826  1.351354  1.358328   1.358328   6839469
# 1  2021-01-01  1.358301  1.359148  1.355138  1.356405   1.356405  11099707
# 2  2021-01-02  1.356437  1.357634  1.354778  1.356590   1.356590  10160156
# 3  2021-01-03  1.356814  1.365397  1.352887  1.352928   1.352928  10087327
# 4  2021-01-04  1.352970  1.355393  1.347542  1.348232   1.348232  19398784

# %%
def function(data,name):
    # add a new column named 'Currency' with value 'BTC'
    for index, row in df1.iterrows():
        data.at[index, 'Currency'] = name

    # print the updated dataframe



function(df1,'BTC')
function(df2,'Etherum')

print(df1)
print(df2)
# Out:
#            Date          Open          High           Low         Close  \
# 0    2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
# 1    2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2    2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 3    2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 4    2021-01-04  32810.949219  33440.218750  28722.755859  31971.914062
# ..          ...           ...           ...           ...           ...
# 424  2022-02-28  37706.000000  43760.457031  37518.214844  43193.234375
# 425  2022-03-01  43194.503906  44793.601562  42952.585938  44354.636719
# 426  2022-03-02  44357.617188  45077.578125  43432.851562  43924.117188
# 427  2022-03-03  43925.195312  44021.578125  41914.750000  42451.789062
# 428  2022-03-06  39397.218750  39625.664062  38219.726562  38748.148438
#
#         Adj Close       Volume Currency
# 0    29001.720703  46754964848      BTC
# ...
